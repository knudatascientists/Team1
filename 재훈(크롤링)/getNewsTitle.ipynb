# %%
# 모듈 불러오기
from urllib.request import urlopen #url 주소 호출 라이브러리
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# %%
# IT 기사 리스트 : 0번째 리스트
list_it = [731, 226, 227, 228, 732, 283, 229, 228]

# 경제
list_economy = [256, 258, 261, 771, 260, 262, 310, 263]

# 사회
list_social = [249, 250, 251, 254, 252, 255, 256, 276, 257]

# 생활 문화
list_life = [241, 239, 240, 237, 238, 376, 242, 243, 244, 348, 245]

# 국제
list_global = [231, 232, 233, 234, 322]

# 스포츠
list_sport = []

# 정치
list_politics = [264, 265, 268, 266, 267, 269]

# %%
list_num = [5, 1, 2, 3, 4, 99, 0]

# 리스트의 리스트
list_list = [list_it, list_economy, list_social, list_life, list_global, list_sport, list_politics]

# %%
def getTitles(date, type) :
    # 리스트의 리스트에서 입력된 리스트를 불러오기
    list_li = list_list[type]
    num = list_num[type]
    if num == 99 :
        print("스포츠 뉴스는 다른 함수를 사용해주시길 바랍니다.")
    else :
        # 타이틀을 담을 리스트
        list_title = []
        for i in range(0, len(list_li)) :
            print(i)
            # 입력한 날짜의 리스트 페이지의 데이터를 저장
            url = (f'https://news.naver.com/main/list.naver?mode=LS2D&sid2={list_li[i]}&mid=shm&sid1=10{num}&date={date}&page=1')
            print(url)
            html = urlopen(url) # url 주소 html로 저장
            soup = BeautifulSoup(html.read(), 'html.parser') # html 데이터 BeautifulSoup으로 요약
            text = soup.find_all('dt')
            j = 1
            for j in range(1, 40, 2) :
                print(j)
                try :
                    te = text[j].text.strip()
                    if len(te) >= 1 : # 내용이 있는 경우에만
                        list_title.append(te)
                        print(te)
                except :
                    continue
        # 데이터를 데이터 프레임으로 변환
        df = pd.DataFrame(list_title)
        # 데이터에 입력했던 라벨 지정
        df['label'] = type
        return df

# %%
df = getTitles('20220913', 0)
# Out:
# 0
# https://news.naver.com/main/list.naver?mode=LS2D&sid2=731&mid=shm&sid1=105&date=20220913&page=1
# 1
# 교보문고, 10인치로 커진 전자책 단말기 'sam10 Plus' 출시
# 3
# "5G가입자 늘리자"…이통3사, 아이폰14 사전예약 알림 '선물' 경쟁
# 5
# 대구은행, 대구FC 경기 티켓 배포…IM뱅크 쿠폰함 활성화
# 7
# 애플 전문가의 '일갈'.."아이폰14, 세분화 전략 실패"
# 9
# 애플, 아이폰 'iOS16' 업데이트…'잠금화면 꾸미기' 내세워
# 11
# '156 6666 6666' 중국 휴대전화번호 경매…시작가 27억원
# 13
# 올해 폴더블폰 출하량 1530만대 전망…성장세 '주춤'
# 15
# 손목 위 전쟁 뜨겁다...스마트워치 뭐 살까?
# 17
# KAIST, '스마트폰 앱 켜면 전시물 내부투시' 증강현실 장치 개발
# 19
# KAIST, '스마트폰 앱 켜면 전시물 내부투시' 증강현실 장치 개발
# 21
# DSCC, "폴더블폰, 올해 판매량 1530만대"
# 23
# 온도센서 첫 탑재했는데...갤워치5·애플워치8 차이점은?
# 25
# 코웨이, 美 IDEA 2022 디자인 어워드 수상
# 27
# [포토] AIIA 조찬포럼 13일 성료
# 29
# 메타, 차세대 VR 기기 유출…모습은?
# 31
# 복지 사각지대 이웃 찾기…오산시, 카카오채널 '돌봄톡' 활성화
# 33
# [게시판] 다올저축은행, 'Fi 매일 정기적금' 특판
# 35
# 인텔-브로드컴, 와이파이7 선점 ‘맞손’
# 37
# "보내기 취소된 메시지입니다"…이제 아이폰도 된다
# 39
# 아이폰14 17% 인상 '한국만 봉?'..中 '동결', 日보다 비싸
# 1
# https://news.naver.com/main/list.naver?mode=LS2D&sid2=226&mid=shm&sid1=105&date=20220913&page=1
# 1
# 박보균 장관 "K-컬처 세계적 인기는 희망·미래 때문"
# 3
# 넷플릭스, 'OTT 쪼개팔기' 페이센스에 서비스중단 요청
# 5
# 사피온 ‘X220’칩, 엔비디아 A2 대비 2.3배 빨라
# 7
# “택시기사가 아닙니다. 파트너입니다” 상생적 혁신 택한 타다의 변신
# 9
# 전국민 절반 쓴 '티맵'…추모공원 제친 추석 인기장소 '이곳'
# 11
# 정보보호 우수사례 대상 공모, 내달 24일까지 접수
# 13
# "성행위 연기해달라"...아바타 친구의 돌변
# 15
# 카카오, 중소 파트너 교육 프로그램 강화
# 17
# 네카오, 메타버스 성범죄·AI 혐오표현 잡는다
# 19
# 국토안전관리원 "공동주택 하자분쟁 해결 도와드립니다"
# 21
# 쿠팡 "쿠팡이츠 매각설 사실무근...법적 대응할 것"
# 23
# 스테이션3, '다방싸인'으로 통합 주거 플랫폼 도약
# 25
# 개인정보보호위원장 바뀐다…이르면 이달 임명
# 27
# 위성방송 스카이라이프에도 '키즈랜드' 선보여
# 29
# “유튜버 보단 그냥 직장 열심히 다니는게”... 평균 소득 비교해보니
# 31
# 추석 티맵 이용자 546만명 돌파…인기 목적지 ‘공항’
# 33
# 샌드박스네트워크 커머스 플랫폼 새단장...“조나단부터 우영우 굿즈까지”
# 35
# LGU+, 인공지능 네트워크 자동화 기술 실증
# 37
# 세탁특공대, 가을 맞이 9월 한 달 15% 할인
# 39
# HBO/HBO맥스, 에미상서 넷플릭스 눌렀다
# 2
# https://news.naver.com/main/list.naver?mode=LS2D&sid2=227&mid=shm&sid1=105&date=20220913&page=1
# 1
# 넷플릭스 '오징어게임' 에미상 6관왕 쾌거
# 3
# [단독] ‘망무임승차방지법’ 공청회 20일 개최…입법 탄력 받나
# 5
# 팬택 IP 사들인 '팬텍'…美서 LG전자에 특허 소송
# 7
# "유튜브, 한국 경제와 사회에 큰 기여"... 대표 5개 채널은?
# 9
# 클래식 음악 전문 채널 토마토클래식, LG헬로비전 런칭
# 11
# 13
# 15
# 17
# 19
# SKT, SK브로드밴드 손잡고 양자암호 국제망 첫 상용화
# 21
# 23
# 25
# 27
# 29
# 31
# 33
# 35
# 37
# 39
# 3
# https://news.naver.com/main/list.naver?mode=LS2D&sid2=228&mid=shm&sid1=105&date=20220913&page=1
# 1
# 3
# 5
# ‘메이드 인 아메리카’ 주문에 K바이오 긴장… 위탁생산 타격 우려
# 7
# 신진 연구자 육성 돕는다...NST, '영 사이언티스트 사업' 연수성과교류회 개최
# 9
# '콘택트렌즈 뒤집힘 알아내는 케이스' 고교생이 발명
# 11
# 셀트리온 ‘베그젤마’ 임상 3상… "오리지날과 생존·안전성 유사"
# 13
# 스마트폰으로 전시물 투시하는 AR 개발
# 15
# 美 "바이오도 미국우선" 공식화…삼바·셀트리온 수출 타격 불가피
# 17
# "ABL바이오 신약 경쟁력 자신…새로운 항암 기술 11월 발표"
# 19
# 보폭 넓히는 셀트리온…ADC·이중항체 도전장
# 21
# 레모넥스 약물 전달기술에 사노피 '러브콜'
# 23
# [포토] SK바사 ‘스카이코비원’ 사전예약자 접종 시작
# 25
# 27
# 29
# 31
# 33
# 35
# 37
# 39
# 4
# https://news.naver.com/main/list.naver?mode=LS2D&sid2=732&mid=shm&sid1=105&date=20220913&page=1

# %%
df[:20]
# Out:
#                                             0  label
# 0          레노버, 차세대 인텔 CPU 탑재 '요가' 7세대 라인업 공개      5
# 1                    나이지리아, 5G 서비스 8월부터 출시 예상      5
# 2         [인터뷰] 리디 “콘텐츠 본부 신설…웹툰 자체제작 경쟁력 강화”      5
# 3                    한종희 부회장 "삼성만의 메타버스 만들 것"      5
# 4   "10위권은 가뿐하다더니…" 검은사막 모바일 100위권 밖으로 '차트아웃'      5
# 5      KT, 수도권 북부·강원권에 AI 서비스로봇 도입 매장 100곳 돌파      5
# 6                          韓·美·中 '폴더블 삼국지' 온다      5
# 7         LGU+ 데이터 커머스 플랫폼 'U+콕' 기념일 맞춤 상품 할인      5
# 8               고려대·포항공대 연합체, 가속기인력양성 기관으로 낙점      5
# 9              과기부, 올해 데이터바우처 지원 사업에 1241억 투입      5
# 10                   디지털 사회문제 해결할 '디지털청' 만들어야      5
# 11                  이통3사, 어린이날 기념 V컬러링 기부 캠페인      5
# 12                     KT, AI로봇 도입 매장 100곳 돌파      5
# 13      KT, VVIP 멤버십 고객님 '생일 축하'…3만원 상당 케익 무료      5
# 14    영국 왕실이 품질 인증했다...삼성 생활가전, '퀸 로열 워런트' 획득      5
# 15               이통3사, 유니세프와 V 컬러링 활용한 기부 캠페인      5
# 16                이동통신 3사, V컬러링' 통한 기부 캠페인 진행      5
# 17                이동통신 3사, V컬러링' 통한 기부 캠페인 진행      5
# 18                   이통3사, V컬러링으로 어린이 돌봄 앞장선다      5
# 19                    이통3사, V컬러링 통한 기부 캠페인 진행      5
